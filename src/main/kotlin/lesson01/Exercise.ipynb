// %% [markdown]
// ## Exercise 1 - Rectangle

// %%
val width: Int = 5
val length: Int = 3

val perimeter = 2 * width + 2 * length
perimeter
// Out:
// 16

// %% [markdown]
// ## Exercise 2 - Equilateral Triangle

// %%
val side = 8
val trianglePerimeter = 3 * side

trianglePerimeter
// Out:
// 24

// %% [markdown]
// ## Exercise 3 - Area of a Circle

// %%
val pi = 3.14
val radius = 5.0
val area = pi * radius * radius

area
// Out:
// 78.5
